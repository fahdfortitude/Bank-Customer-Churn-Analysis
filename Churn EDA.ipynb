# %% [markdown]
# # Loading and Exploring Data Sets

# %% [markdown]
# ## Loading The Data

# %%
#import the necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#hide jupyter notebook warnings
import warnings
warnings.simplefilter('ignore')

# %%
#load the data
churn= pd.read_csv(r'C:\Users\User\Downloads\Machine Learning\Machine Learning\Customer_Churn\Customer_Churn\churn_prediction.csv')

# %%
churn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28382 entries, 0 to 28381
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   customer_id                     28382 non-null  int64
#  1   vintage                         28382 non-null  int64
#  2   age                             28382 non-null  int64
#  3   gender                          27857 non-null  object
#  4   dependents                      25919 non-null  float64
#  5   occupation                      28302 non-null  object
#  6   city                            27579 non-null  float64
#  7   customer_nw_category            28382 non-null  int64
#  8   branch_code                     28382 non-null  int64
#  9   days_since_last_transaction     25159 non-null  float64
#  10  current_balance                 28382 non-null  float64
#  11  previous_month_end_balance      28382 non-null  float64
#  12  average_monthly_balance_prevQ   28382 non-null  float64
#  13  average_monthly_balance_prevQ2  28382 non-null  float64
#  14  current_month_credit            28382 non-null  float64
#  15  previous_month_credit           28382 non-null  float64
#  16  current_month_debit             28382 non-null  float64
#  17  previous_month_debit            28382 non-null  float64
#  18  current_month_balance           28382 non-null  float64
#  19  previous_month_balance          28382 non-null  float64
#  20  churn                           28382 non-null  int64
# dtypes: float64(13), int64(6), object(2)
# memory usage: 4.5+ MB

# %%
#quick look at the data
churn.head()
# Out:
#    customer_id  vintage  age gender  dependents     occupation    city  \
# 0            1     3135   66   Male         0.0  self_employed   187.0
# 1            2      310   35   Male         0.0  self_employed     NaN
# 2            4     2356   31   Male         0.0       salaried   146.0
# 3            5      478   90    NaN         NaN  self_employed  1020.0
# 4            6     2531   42   Male         2.0  self_employed  1494.0
#
#    customer_nw_category  branch_code  days_since_last_transaction  ...  \
# 0                     2          755                        224.0  ...
# 1                     2         3214                         60.0  ...
# 2                     2           41                          NaN  ...
# 3                     2          582                        147.0  ...
# 4                     3          388                         58.0  ...
#
#    previous_month_end_balance  average_monthly_balance_prevQ  \
# 0                     1458.71                        1458.71
# 1                     8704.66                        7799.26
# 2                     5815.29                        4910.17
# 3                     2291.91                        2084.54
# 4                     1401.72                        1643.31
#
#    average_monthly_balance_prevQ2  current_month_credit  \
# 0                         1449.07                  0.20
# 1                        12419.41                  0.56
# 2                         2815.94                  0.61
# 3                         1006.54                  0.47
# 4                         1871.12                  0.33
#
#    previous_month_credit  current_month_debit  previous_month_debit  \
# 0                   0.20                 0.20                  0.20
# 1                   0.56              5486.27                100.56
# 2                   0.61              6046.73                259.23
# 3                   0.47                 0.47               2143.33
# 4                 714.61               588.62               1538.06
#
#    current_month_balance  previous_month_balance  churn
# 0                1458.71                 1458.71      0
# 1                6496.78                 8787.61      0
# 2                5006.28                 5070.14      0
# 3                2291.91                 1669.79      1
# 4                1157.15                 1677.16      1
#
# [5 rows x 21 columns]

# %% [markdown]
# ##### A snippet look at the descriptive statistics of the numerical columns

# %%
churn.describe()
# Out:
#         customer_id       vintage           age    dependents          city  \
# count  28382.000000  28382.000000  28382.000000  25919.000000  27579.000000
# mean   15143.508667   2364.336446     48.208336      0.347236    796.109576
# std     8746.454456   1610.124506     17.807163      0.997661    432.872102
# min        1.000000    180.000000      1.000000      0.000000      0.000000
# 25%     7557.250000   1121.000000     36.000000      0.000000    409.000000
# 50%    15150.500000   2018.000000     46.000000      0.000000    834.000000
# 75%    22706.750000   3176.000000     60.000000      0.000000   1096.000000
# max    30301.000000  12899.000000     90.000000     52.000000   1649.000000
#
#        customer_nw_category   branch_code  days_since_last_transaction  \
# count          28382.000000  28382.000000                 25159.000000
# mean               2.225530    925.975019                    69.997814
# std                0.660443    937.799129                    86.341098
# min                1.000000      1.000000                     0.000000
# 25%                2.000000    176.000000                    11.000000
# 50%                2.000000    572.000000                    30.000000
# 75%                3.000000   1440.000000                    95.000000
# max                3.000000   4782.000000                   365.000000
#
#        current_balance  previous_month_end_balance  \
# count     2.838200e+04                2.838200e+04
# mean      7.380552e+03                7.495771e+03
# std       4.259871e+04                4.252935e+04
# min      -5.503960e+03               -3.149570e+03
# 25%       1.784470e+03                1.906000e+03
# 50%       3.281255e+03                3.379915e+03
# 75%       6.635820e+03                6.656535e+03
# max       5.905904e+06                5.740439e+06
#
#        average_monthly_balance_prevQ  average_monthly_balance_prevQ2  \
# count                   2.838200e+04                    2.838200e+04
# mean                    7.496780e+03                    7.124209e+03
# std                     4.172622e+04                    4.457581e+04
# min                     1.428690e+03                   -1.650610e+04
# 25%                     2.180945e+03                    1.832507e+03
# 50%                     3.542865e+03                    3.359600e+03
# 75%                     6.666887e+03                    6.517960e+03
# max                     5.700290e+06                    5.010170e+06
#
#        current_month_credit  previous_month_credit  current_month_debit  \
# count          2.838200e+04           2.838200e+04         2.838200e+04
# mean           3.433252e+03           3.261694e+03         3.658745e+03
# std            7.707145e+04           2.968889e+04         5.198542e+04
# min            1.000000e-02           1.000000e-02         1.000000e-02
# 25%            3.100000e-01           3.300000e-01         4.100000e-01
# 50%            6.100000e-01           6.300000e-01         9.193000e+01
# 75%            7.072725e+02           7.492350e+02         1.360435e+03
# max            1.226985e+07           2.361808e+06         7.637857e+06
#
#        previous_month_debit  current_month_balance  previous_month_balance  \
# count          2.838200e+04           2.838200e+04            2.838200e+04
# mean           3.339761e+03           7.451133e+03            7.495177e+03
# std            2.430111e+04           4.203394e+04            4.243198e+04
# min            1.000000e-02          -3.374180e+03           -5.171920e+03
# 25%            4.100000e-01           1.996765e+03            2.074408e+03
# 50%            1.099600e+02           3.447995e+03            3.465235e+03
# 75%            1.357553e+03           6.667958e+03            6.654693e+03
# max            1.414168e+06           5.778185e+06            5.720144e+06
#
#               churn
# count  28382.000000
# mean       0.185329
# std        0.388571
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %% [markdown]
# ##### Inference drawn
# 1. There are 28382 customers info in the data sets
# 2. The bank's youngest customer is a year old and it's eldest is 90
# 3. Cities have been concealed using numbers, thus, using them as nominal variable for predicting customers churn might be difficult if there are too many unique cities
# 4. All the customers whose information were include in the datasets have transacted with the bank within the past 365 days.
# 5. The Transactional information columns seems skewed to the right

# %% [markdown]
# ### Exploratory Data Analysis

# %%
churn['churn'].value_counts(normalize=True).plot(kind='bar')
plt.xticks([0,1],labels=['No', 'Yes'], rotation=0)
plt.title('Churned')
# Out:
# Text(0.5, 1.0, 'Churned')

# %% [markdown]
# Most of the bank customers do not stop transacting with the bank.

# %% [markdown]
# ##### <t><i>Demographic Characteristics</i></t>

# %%
fig, ax=plt.subplots(4,2,figsize=(14,14))
axis=ax.ravel()
sns.countplot(x='gender',data=churn, ax=axis[0])
axis[0].set_title('Gender Counts')

sns.countplot(x='gender', hue='churn',data=churn, ax=axis[1])
axis[1].set_title('Gender Churns')

sns.countplot(x='dependents', data=churn, ax=axis[2])
axis[2].set_xticklabels([text.get_text() for text in axis[2].get_xticklabels()], rotation=90)
axis[2].set_title('No of Dependents')

sns.countplot(x='dependents', hue='churn',data=churn[churn['dependents']<5], ax=axis[3])
axis[3].set_title("Churn for up till 5 dependencies")

axis[4].hist(churn['age'])
axis[4].set_title('Age Distribution')
for i in range(2):
    axis[5].hist(churn[churn['churn']==i]['age'], label=str(i))
axis[5].legend(title='Churn')
axis[5].set_title('Age Distribution by churn')

sns.countplot(x='occupation', data=churn, ax=axis[6])
axis[6].set_title('Occupation')

sns.countplot(x='occupation', hue='churn',data=churn, ax=axis[7])
axis[7].set_title('Occupation Churn')

plt.tight_layout()
# sns.histplot(x='age', hue='gender',data=churn, ax=axis[2])
# sns.histplot(x='age', hue='gender',data=churn, ax=axis[2])

# %%
np.count_nonzero(churn['city'].unique())
# Out:
# 1604

# %% [markdown]
# ###### Demographic Characteristics Exploration Findings
# * There are more male customers than female customers, there seems to be little variance in the churn rate of both genders which is low for both. The rates will be examined in the next cell
# * Vast Majority of the customers and single, in essence most of the customers with dependents have between 1 and 4 people depending on them, however some have ridiculously high amount of dependents up to 52,this seems unrealistic, a table showing the exact percentage of the observations that fall in the categories will necessary to determine whether to exclude this cases or not when preparing the data sets for predictive analytics. Nevertheless the churn rate for people with no dependents and up to four dependents have similar churn rates.
# * The bank customers are between 1 and 90 years old, majority of the customers fall between 19 and about 70 years old, there also seems to be substantial number of people between 70 and 90 years, the churn rate of each age is similar.
# * Occupation seems to have the most variations in churn rates, little though, the majority of the customers are self employed and are more likely to churn than the rest of the occuptions. the variations in churn rates seems to increase with the number of customers in that category

# %%
sns.distplot(churn['vintage'])
# Out:
# <AxesSubplot:xlabel='vintage', ylabel='Density'>

# %%
pd.concat([churn[churn['gender']=='Female']['churn'].value_counts(normalize=True).rename('Female Churn %', axis=1),
           churn[churn['gender']=='Male']['churn'].value_counts(normalize=True).rename('Male Churn %', axis=1)], 
          axis=1) *100
# Out:
#    Female Churn %  Male Churn %
# 0       82.447608      80.84965
# 1       17.552392      19.15035

# %%
dependents=churn['dependents'].value_counts(normalize=True).sort_index()
dependents=dependents.cumsum()
dependents.name='Cummualtive Frequency'
dependents=pd.DataFrame(dependents)


#printing the cummulative frequency of the dependenta
dependents.style.format('{:.2%}')
# Out:
# <style  type="text/css" >
# </style><table id="T_9d4268cc_767c_11eb_ac18_e1441bed2305" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Cummualtive Frequency</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9d4268cc_767c_11eb_ac18_e1441bed2305level0_row0" class="row_heading level0 row0" >0.0</th>
#                         <td id="T_9d4268cc_767c_11eb_ac18_e1441bed2305row0_col0" class="data row0 col0" >82.70%</td>
#             </tr>
#             <tr>
#                         <th id="T_9d4268cc_767c_11eb_ac18_e1441bed2305level0_row1" class="row_heading level0 row1" >1.0</th>
#                         <td id="T_9d4268cc_767c_11eb_ac18_e1441bed2305row1_col0" class="data row1 col0" >88.08%</td>
#             </tr>
#             <tr>
#                         <th id="T_9d4268cc_767c_11eb_ac18_e1441bed2305level0_row2" class="row_heading level0 row2" >2.0</th>
#                         <td id="T_9d4268cc_767c_11eb_ac18_e1441bed2305row2_col0" class="data row2 col0" >96.38%</td>
#             </tr>
#             <tr>
#                         <th id="T_9d4268cc_767c_11eb_ac18_e1441bed2305level0_row3" class="row_heading level0 row3" >3.0</th>
#                         <td id="T_9d4268cc_767c_11eb_ac18_e1441bed2305row3_col0" class="data row3 col0" >99.08%</td>
#             </tr>
#             <tr>
#                         <th id="T_9d4268cc_767c_11eb_ac18_e1441bed2305level0_row4" class="row_heading level0 row4" >4.0</th>
#                         <td id="T_9d4268cc_767c_11eb_ac18_e1441bed2305row4_col0" class="data row4 col0" >99.77%</td>
#             </tr>
#             <tr>
#                         <th id="T_9d4268cc_767c_11eb_ac18_e1441bed2305level0_row5" class="row_heading level0 row5" >5.0</th>
#                         <td id="T_9d4268cc_767c_11eb_ac18_e1441bed2305row5_col0" class="data row5 col0" >99.93%</td>
#             </tr>
#             <tr>
#                         <th id="T_9d4268cc_767c_11eb_ac18_e1441bed2305level0_row6" class="row_heading level0 row6" >6.0</th>
#                         <td id="T_9d4268cc_767c_11eb_ac18_e1441bed2305row6_col0" class="data row6 col0" >99.96%</td>
#             </tr>
#             <tr>
#                         <th id="T_9d4268cc_767c_11eb_ac18_e1441bed2305level0_row7" class="row_heading level0 row7" >7.0</th>
#                         <td id="T_9d4268cc_767c_11eb_ac18_e1441bed2305row7_col0" class="data row7 col0" >99.97%</td>
#             </tr>
#             <tr>
#                         <th id="T_9d4268cc_767c_11eb_ac18_e1441bed2305level0_row8" class="row_heading level0 row8" >8.0</th>
#                         <td id="T_9d4268cc_767c_11eb_ac18_e1441bed2305row8_col0" class="data row8 col0" >99.98%</td>
#             </tr>
#             <tr>
#                         <th id="T_9d4268cc_767c_11eb_ac18_e1441bed2305level0_row9" class="row_heading level0 row9" >9.0</th>
#                         <td id="T_9d4268cc_767c_11eb_ac18_e1441bed2305row9_col0" class="data row9 col0" >99.98%</td>
#             </tr>
#             <tr>
#                         <th id="T_9d4268cc_767c_11eb_ac18_e1441bed2305level0_row10" class="row_heading level0 row10" >25.0</th>
#                         <td id="T_9d4268cc_767c_11eb_ac18_e1441bed2305row10_col0" class="data row10 col0" >99.98%</td>
#             </tr>
#             <tr>
#                         <th id="T_9d4268cc_767c_11eb_ac18_e1441bed2305level0_row11" class="row_heading level0 row11" >32.0</th>
#                         <td id="T_9d4268cc_767c_11eb_ac18_e1441bed2305row11_col0" class="data row11 col0" >99.99%</td>
#             </tr>
#             <tr>
#                         <th id="T_9d4268cc_767c_11eb_ac18_e1441bed2305level0_row12" class="row_heading level0 row12" >36.0</th>
#                         <td id="T_9d4268cc_767c_11eb_ac18_e1441bed2305row12_col0" class="data row12 col0" >99.99%</td>
#             </tr>
#             <tr>
#                         <th id="T_9d4268cc_767c_11eb_ac18_e1441bed2305level0_row13" class="row_heading level0 row13" >50.0</th>
#                         <td id="T_9d4268cc_767c_11eb_ac18_e1441bed2305row13_col0" class="data row13 col0" >100.00%</td>
#             </tr>
#             <tr>
#                         <th id="T_9d4268cc_767c_11eb_ac18_e1441bed2305level0_row14" class="row_heading level0 row14" >52.0</th>
#                         <td id="T_9d4268cc_767c_11eb_ac18_e1441bed2305row14_col0" class="data row14 col0" >100.00%</td>
#             </tr>
#     </tbody></table>

# %%
#percentage of churn across occupation
occupation_churn_pivot=pd.pivot_table(data=churn, index='occupation', columns='churn', values='customer_id',aggfunc='count' )
occupation_churn_pivot.div(occupation_churn_pivot.sum(1), axis=0).sort_values(by=1, ascending=False).style.format('{:.2%}')
# Out:
# <style  type="text/css" >
# </style><table id="T_9d4acbd3_767c_11eb_8438_e1441bed2305" ><thead>    <tr>        <th class="index_name level0" >churn</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>    </tr>    <tr>        <th class="index_name level0" >occupation</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9d4acbd3_767c_11eb_8438_e1441bed2305level0_row0" class="row_heading level0 row0" >self_employed</th>
#                         <td id="T_9d4acbd3_767c_11eb_8438_e1441bed2305row0_col0" class="data row0 col0" >80.16%</td>
#                         <td id="T_9d4acbd3_767c_11eb_8438_e1441bed2305row0_col1" class="data row0 col1" >19.84%</td>
#             </tr>
#             <tr>
#                         <th id="T_9d4acbd3_767c_11eb_8438_e1441bed2305level0_row1" class="row_heading level0 row1" >salaried</th>
#                         <td id="T_9d4acbd3_767c_11eb_8438_e1441bed2305row1_col0" class="data row1 col0" >82.89%</td>
#                         <td id="T_9d4acbd3_767c_11eb_8438_e1441bed2305row1_col1" class="data row1 col1" >17.11%</td>
#             </tr>
#             <tr>
#                         <th id="T_9d4acbd3_767c_11eb_8438_e1441bed2305level0_row2" class="row_heading level0 row2" >student</th>
#                         <td id="T_9d4acbd3_767c_11eb_8438_e1441bed2305row2_col0" class="data row2 col0" >84.26%</td>
#                         <td id="T_9d4acbd3_767c_11eb_8438_e1441bed2305row2_col1" class="data row2 col1" >15.74%</td>
#             </tr>
#             <tr>
#                         <th id="T_9d4acbd3_767c_11eb_8438_e1441bed2305level0_row3" class="row_heading level0 row3" >retired</th>
#                         <td id="T_9d4acbd3_767c_11eb_8438_e1441bed2305row3_col0" class="data row3 col0" >84.93%</td>
#                         <td id="T_9d4acbd3_767c_11eb_8438_e1441bed2305row3_col1" class="data row3 col1" >15.07%</td>
#             </tr>
#             <tr>
#                         <th id="T_9d4acbd3_767c_11eb_8438_e1441bed2305level0_row4" class="row_heading level0 row4" >company</th>
#                         <td id="T_9d4acbd3_767c_11eb_8438_e1441bed2305row4_col0" class="data row4 col0" >90.00%</td>
#                         <td id="T_9d4acbd3_767c_11eb_8438_e1441bed2305row4_col1" class="data row4 col1" >10.00%</td>
#             </tr>
#     </tbody></table>

# %%
label=['Minor', 'Young Adult', "Middle Age","Old Age"]
Age_Group = pd.cut(churn['age'],[0,18,35,65,100], labels=label)
churn['Age_group']=Age_Group

# %%
sns.distplot(churn[churn['Age_group']=="Minor"]['age'])
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
sns.countplot('Age_group',hue='churn', data=churn)
# Out:
# <AxesSubplot:xlabel='Age_group', ylabel='count'>

# %% [markdown]
# #### Customer Relationship Exploration

# %%
print('The bank has {} unique branches'.format(np.count_nonzero(churn['branch_code'].unique())))
# Out:
# The bank has 3185 unique branches

# %%
fig,ax=plt.subplots(2,1, figsize=(10,8))
sns.countplot(data=churn, x='customer_nw_category', hue='churn', ax=ax[0])
sns.distplot(churn['days_since_last_transaction'], ax=ax[1])
# Out:
# <AxesSubplot:xlabel='days_since_last_transaction', ylabel='Density'>

# %%
benchmark="""current_balance
previous_month_end_balance
average_monthly_balance_prevQ
average_monthly_balance_prevQ2
current_month_credit
previous_month_credit
current_month_debit
previous_month_debit
current_month_balance
previous_month_balance""".split('\n')

# %%
len(benchmark)
# Out:
# 10

# %%
fig, ax=plt.subplots(5,2, figsize=(12,10))
for col, axis in zip(benchmark, ax.ravel()):
    sns.distplot(churn[col], ax=axis, axlabel=f'Distribution of {col}')
plt.tight_layout()

# %% [markdown]
# All the transactional history data sets are skewed to the right, hence, it is extremely difficult to examine the distributions. As a personal rule of thumb, next line of action is to visualize 95% of the data sets, this is suppose to exclude the outliers from the visualizations and visual examination of the distribution easier.

# %%
fig, ax=plt.subplots(5,2, figsize=(12,10))
for col, axis in zip(benchmark, ax.ravel()):
    per_90=churn[col][churn[col]<=np.percentile(churn[col],95)]
    sns.distplot(per_90, ax=axis, axlabel=f'Distribution of {col}')
plt.tight_layout()

# %% [markdown]
# The Foregoing distribution shows that despite the fact that some customers transactional history are in millons, most of the bank's customers transactional history is less than 25000 for all the benchmarks, in fact most seem to have less than 5000. Also some customers have negative balances up to 5000.
# Because of the conspicuous presence of outliers, the benchmark columns will need to logged when preprocessing them for machine learning.
# It is important to note that for metrics with negative number the logarithimic equation is <br><br></br></br>
# A = Log( Y +  abs(min(Y))+ 1)<br></br>
# where Y is a benchmark column values and abs(min(Y)) is the absolute value of the maximum negative number
# <br><br></br></br>
# Next a look at the correlation of the baseline

# %%
plt.figure(figsize=(10,10))
sns.heatmap(churn[benchmark].corr(), cmap='coolwarm', annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# One will expect that previous month balance is strongly correlated with current month balances, it goes without saying that the very correlation values of over 90 validate ones apriori expectation.<b></b>
# It is important to note that previous month credit and debits are weakly correlated with their current month's values, Also credit and debit balances for example are weakly correlated.

# %% [markdown]
# ###### Benchmarks and churn

# %%
# benchmark=['current_balance', 'current_month_credit', 'current_month_debit']

fig, ax =plt.subplots(5,2, figsize=(16,18), sharex=True)


for col, axis in zip(benchmark, ax.ravel()):
    per_95=np.round(np.percentile(churn[col],95))
    sns.boxplot(x='churn', y=col, data=churn[churn[col]<=per_95], ax=axis)

# %% [markdown]
# ###### Benchmark and Age Group

# %%
fig, ax =plt.subplots(5,2, figsize=(16,15),)
for col, axis in zip(benchmark, ax.ravel()):
    per_95=np.round(np.percentile(churn[col],95))
    sns.boxplot(x='Age_group', y=col, data=churn[churn[col]<=per_95], ax=axis)
plt.tight_layout()

# %%
#save the data as pkl

churn.to_pickle('churn.pkl')

# %% [markdown]
# ### Conclusion
#
# There is a need to draw the cotton on Exploratory Data analysis, one could go on and on but, the insights draw so far seem enough for preprocessing the data for machine learning, which is exactly the next on the list,
